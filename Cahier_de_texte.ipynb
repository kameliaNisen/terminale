# %% [markdown]
# # Séance 49 :  8 Février 2021 de 10h à 12h - M. Billouard
# ## Activité en classe :
#
# * **Bloc1/Arbres**
#     * Cours découverte des graphes:<br>
#             TD Graphe (Diskstra) modification de la liste d'ajacence
#
# # Séance 48 :  5 Février 2021 de 8h à 10h - M. Billouard
# ## Activité en classe :
#
# * **Bloc1/Arbres**
#     * Parcours d'un arbre binaire :<br>
#         Fin du Td arbre binaire de recherche
#
# # Séance 47 :  04 février 2021 de 8h à 10h - M. Seynave
# ## Activité en classe :
#
# * **bloc1/files**
#     * TD files : jeu de bataille
#
# ## Pour la prochaine séance :
#
# * **DS**. A revoir :
#     * Programmation orientée objet
#     * Structures de piles et de files
#
# # Séance 46 :  1 Février 2021 de 10h à 12h - M. Billouard
# ## Activité en classe :
#
# * **Bloc1/Arbres**
#     * Parcours d'un arbre binaire :<br>
#         Fin du Td arbre binaire en utilisant les classes
#     * Cours Arbre binaire de recherche (abr)
#         Td arbre binaire de recherche
#
#
# # Séance 45 :  29 janvier 2021 de 8h à 10h - M. Billouard
# ## Activité en classe :
#
# * **Bloc1/Arbres**
#     * Parcours d'un arbre binaire :<br>
#         Poursuite du Td arbre binaire en utilisant les classes
#
# # Séance 44 :  28 janvier 2021 de 8h à 10h - M. Seynave
# ## Activité en classe :
#
# * **bloc1/piles**
#     * TD piles : Correction du TD "bon parenthésage"
#     * TD piles : Notation polonaise
#
# ## Pour la prochaine séance :
#
#
# # Séance 45 :  25 janvier 2021 de 10h à 12h - M. Billouard
# ## Activité en classe :
#
# * **Bloc1/Arbres**
#     * Parcours d'un arbre binaire :<br>
#         Fin Td Parcours d'un arbre binaire sous python
#         Td arbre binaire en utilisant les classes
#
# # Séance 44 :  22 janvier 2021 de 8h à 10h - M. Billouard
# ## Activité en classe :
#
# * **Bloc1/Arbres**
#     * Parcours d'un arbre binaire :<br>
#         Td Parcours d'un arbre binaire sous python
#
# # Séance 43 :  21 janvier 2021 de 8h à 10h - M. Seynave
# ## Activité en classe :
#
# * **Bloc1/pile**
#     * Correction des questions 1 et 2 de l'exercice1 du sujet 0
#
# * **Bloc1/file**
#     * cours files
#     * TD files
#
# ## Pour la prochaine séance :
#
# * **Bloc1/file**
#     * TD files : terminer la première implémentation et l'exercice 1 (sur l'imprimante) (à déposer dans votre github)
#
#
# # Séance 42 :  18 janvier 2021 de 10h à 12h - M. Billouard
# ## Activité en classe :
#
# * **Bloc1/Arbres**
#     * Les Arbres Binaires :<br>
#         Td Calcul hauteur et profondeur sous python
#
# # Séance 41 :  15 janvier 2021 de 8h à 10h - M. Seynave
# ## Activité en classe :
#
# * **Bloc1/pile**
#    * Cours piles
#    * TD piles
#
# ## Pour la prochaine séance :
#
# * **Bloc1/pile**
#    * exercice_pile.pdf  : A faire sur feuille. Vous êtes susceptible de passer au tableau et d'être noté (aucune excuse acceptée !)
# *(Remarque : au cas où le pdf ne s'affiche pas sur github, il est aussi disponible dans pronote)*
#
# # Séance 40 :  11 janvier 2021 de 10h à 12h - M. Billouard
# ## Activité en classe :
#
# * **Bloc1/Arbres**
#    * Les Arbres
#    * Les Arbres Binaires
#
# # Séance 39 : 8 janvier 2021 de 8h à 10h - M. Billouard
# ## Activité en classe :
#
# * **Correction Evaluation**
# * **Bloc1/Arbres**
#    * Cours Arbres
#
# # Séance 38 :  7 janvier 2021 de 8h à 10h - M. Seynave
# ## Activité en classe :
#
# * **bloc1/POO**
#     * Cours complément à la POO (partie sur méthodes spéciales)
#     * TD POO : exercices 3, 4 et 5
#
# ## Pour la prochaine séance :
#
# * **bloc1/POO** : terminer les exercices 3, 4 et 5 du TD POO
#
# # Séance 37 : 4 janvier 2021 de 10h à 12h - M. Billouard
# ## Activité en classe :
#
#    * Evaluation : Protocoles réseaux , ordonnancement
#
# # Séance 36 : 18 décembre 2020 de 8h à 10h - M. Billouard
# ## Activité en classe :
#
# * **Activité Python**  (4 élèves)
#
# # Séance 36 : 18 décembre 2020 de 8h à 10h - M. Billouard
# ## Activité en classe :
#
# * **Activité Python**  (4 élèves)
#
#
# # Séance 35 : 17 décembre 2020 de 9h à 11h - M. Seynave
# ## Activité en classe :
#
# * **bloc1/POO**
#     * TD_POO : correction de l'exercice1
#     * Cours complément à la POO (sauf partie sur méthodes spéciales)
#     * TD_POO : exercices 2.1
#
# ## Pour la prochaine séance :
#
# * **bloc1/POO** :
#     * TD_POO : exercice 3
#
# # Séance 34 : 14 décembre 2020 de 10h à 12h - M. Billouard
# ## Activité en classe :
#
# * **bloc3**
#     * Sécurisation des données / cryptographie (fin)
#
#     * Points sur l'evaluation du 18 (question/reponse)
#
# # Séance 33 : 11 décembre 2020 de 8h à 10h - M. Billouard
# ## Activité en classe :
#
# * **bloc3**
#     * Sécurisation des données / cryptographie
#
# # Séance 32 : 10 décembre 2020 de 9h à 11h - M. Seynave
# ## Activité en classe :
#
# * **bloc1/POO**
#     * Cours initiation à la Programmation orientée objet
#     * TD_POO : exercice1
#
# ## Pour la prochaine séance :
# * **bloc1/POO**
#     * TD POO (exercice1)
#
# # Séance 31 : 7 décembre 2020 de 10h à 12h - M. Billouard
# ## Activité en classe :
#
# * bloc 3
#     * Les protocoles réseaux
#     * TP Simulation réseaux
#
# # Séance 30 : 4 décembre 2020 de 8h à 10h - M. Billouard
# ## Activité en classe :
#
# * bloc 3
#     * (1) Protocole OSPF (fin)
#
# ## Pour la prochaine séance :
#     * Revoir l'ensemble :
#         * Algorithme d'ordonnancement
#         * Les blocages et interblocages
#         * Protocoles de routage
#     * Evaluation Le 18 Decembre
#
# # Séance 29 : 3 décembre 2020 de 9h à 11h - M. Seynave
# ## Activité en classe :
#
# * **bloc4/recursivité**
#     * TD_recursivité : correction des exercices 6 et 10
#     * Faire les exercices au choix parmi : TD_recursivité (exercices 7, 8, 9) + TD fractales
#
# ## Pour la prochaine séance :
# * **bloc4/recursivité**
#     * TD recursivité : Exercices 7.1 et 7.2
#     * TD fractales : Exercices 0 et 1
#
#
# # Séance 28 : 29 novembre 2020 de 10h à 12h - M. Billouard
# ## Activité en classe :
#
# * bloc 3
#     * (1) Protocole RIP
#     * (2) Protocole OSPF
#
# ## Pour la prochaine séance :
#     * Revoir l'ensemble :
#         * Algorithme d'ordonnancement
#         * Les blocages et interblocages
#         * Protocoles de routage
#
#
# # Séance 27 : 27 novembre 2020 de 8h à 10h - M. Billouard
# ## Activité en classe :
#
# * bloc 3
#     * (1) Protocoles de routages
#     * (2) Td Protocole de routage (Filius)
#
# # Séance 25 : 23 novembre 2020 de 10h à 12h - M. Billouard
# ## Activité en classe :
#
# * bloc 3
#     * (1) Blocage et interblocage
#     * (2) Les réseaux informatiques
#     * (3) Protocoles de routages
#
# # Séance 24 : 20 novembre 2020 de 8h à 10h - M. Billouard
# ## Activité en classe :
#
# * bloc 3
#     * (1) Td L'Ordonnancement Exercice 4
#        * FCFS Premier arrivé premier servi
#        * SFJ travail le plus court d'abord
#        * RR (tourniquet Round Robin)
#        * Avec et sans Réquisition
#     * (2) Blocage et interblocage
#
# # Séance  23 : 19 novembre 2020 de 9h à 11h - M. Seynave
# ## Activité en classe :
#
# * bloc 4/recursivite
#     * Correction de l'exercice 4
#     * fin du cours récursivité
#     * Exercice 5
#
# ## Pour la prochaine séance :
#
# * bloc 4
#      * TD recursivité : Exercice 6 et 10
#
#
# # Séance 22 : 16 novembre 2020 de 10h à 12h - M. Billouard
# ## Activité en classe :
#
# * bloc 3
#     * (1) Td L'Ordonnancement Exercice 2 & 3
#        * FCFS Premier arrivé premier servi
#        * SFJ travail le plus court d'abord
#        * RR (tourniquet Round Robin)
#        * Avec et sans Réquisition
#
# ## Pour la prochaine séance :
#     * Revoir le cours sur l'ordonnancement
#
# # Séance 21 : 13 novembre 2020 de 8h à 10h - M. Billouard
# ## Activité en classe :
#
# * bloc 3
#     * (1) Td L'Ordonnancement Exercice 1
#        * FCFS Premier arrivé premier servi
#        * SFJ travail le plus court d'abord
#        * RR (tourniquet Round Robin)
#        * Avec et sans Réquisition
#
# * Exercice PPMS attentat
#
# ## Pour la prochaine séance :
#     * Revoir le cours sur l'ordonnancement
#
# # Séance  19 : 12 novembre 2020 de 9h à 11h - M. Seynave
# ## Activité en classe :
#
# * bloc 4/recursivite
#     * Correction de l'exercice 2
#     * Exercices 3 et 4
#
#
# # Séance 20 : 9 novembre 2020 de 10h à 12h - M. Billouard
# ## Activité en classe :
#
# * bloc 3
#     * (1) L'Ordonnancement
#     * (2) L'Ordonnancement algorithme
#
# ## Pour la prochaine séance :
#     * Revoir le cours sur l'ordonnancement

# %% [markdown]
# # Séance 19 : 6 novembre 2020 de 8h à 10h - M. Billouard
# ## Activité en classe :
#
# * bloc 3
#     * (1) Point sur la continuité pédagogique si besoin
#     * (2) Les Os
#     * (3) Les processus
#     * (4) Td Les processus
#
# ## Pour la prochaine séance :
#     * Revoir les processus

# %% [markdown]
# # Séance  19 : 5 novembre 2020 de 9h à 1h - M. Seynave
# ## Activité en classe :
#
# * bloc 4
#     * Cours récursivité (jusqu'à la notion de pile mémoire)
#     * TD récursivité (exercice 1)
#
# ## Pour la prochaine séance :
#
# * bloc 4
#      * TD recursivité : Exercice 2 (à déposer dans github)

# %% [markdown]
# # Séance  18 : 2 novembre 2020 de 10h à 12h - M. Billouard
# ## Activité en classe :
#
# * Td Soc
# * Hommage à M. Samuel Paty
#   * Lettre de Jean Jaurès aux Instituteurs et Institutrices
#   * Minute de silence
#
# ## Pour la prochaine séance :
#
# A venir

# %% [markdown]
# # Séance  17 : 15 octobre 2020 de 9h à 11h - M. Seynave
# ## Activité en classe :
#
# * Devoir Surveillé sur les tris
#
# ## Pour la prochaine séance :
#
# Faire le DM `bloc4/DM_vacances_toussaint` **SUR FEUILLE** . Il est très court !!

# %% [markdown]
# # Séance  18 : 16 octobre 2020 de 8h à 10h - M. Billouard
# ## Activité en classe :
#
#     * (1) System on a Chip "SOC"
#     * (2) Td Soc
#     * (3) Fin Td Exploitation d'une Bdd sous Python
#
# ## Pour la prochaine séance :
#
# Trouver les caractéristiques d'un Soc pilotant un de vos appareils domestiques (Hors smartphone).
# Organiser votre Github /blocx/TD...
#
# # Séance  16 : 12 octobre 2020 de 10h à 12h - M. Billouard
# ## Activité en classe :
#
#     * (1) Architecture matériel
#     * (2) Td Simulateur CPU
#     * (3) Entrainement Pix
#
#
# # Séance  15 : 9 octobre 2020 de 8h à 10h - M. Billouard
# ## Activité en classe :
#
#     * (1) Td Exploitation d'une Bdd sous Python
#     * (2) Présentation plateforme Pix
#
# ## Pour la prochaine séance :
#
#     * Continuer le Td Exploitation d'une Bdd sous Python
#
# # Séance  14 : 8 octobre 2020 de 9h à 11h - M. Seynave
# ## Activité en classe :
#
# * **Revisions_premiere**
#     * (1) TD_tris : correction de l'exercice 5
#     * (2) TD tris : exercices 9 et 10
#     * (3) Rappel sur la documentation d'une fonction
#
# ## Pour la prochaine séance :
#
# * Réviser tout ce qui a été vu sur les tris : DS la semaine prochaine (2 heures). Retravailler surtout les exercices sur les tris (correction disponible sur github). En cas d'absence, le DS sera rattrapé !!
#
#
# # Séance  13 : 5 octobre 2020 de 10h à12h - M. Billouard
# ## Activité en classe :
#
#     * (1) Td Exploitation d'une Bdd sous Python
#
# ## Pour la prochaine séance :
#
#     *  Td Bdd "immeuble" jusque Question 15
#
# # Séance  12 : 2 octobre 2020 de 10h à12h - M. Billouard
# ## Activité en classe :
#
#     * (1) Correction du Td Bdd "immeuble" jusque question 10
#     * (2) Td Exploitation d'une Bdd sous Python
#
# ## Pour la prochaine séance :
#
#     * Finir Td Bdd "immeuble"
#     (chaque requête doit être sauvegardée sous forme de vue "create view .... as .....)
#
# # Séance  11 : 1 octobre 2020 de 9h à 11h - M. Seynave
# ## Activité en classe :
#
# * **Revisions_premiere**
#     * (1) correction des exercices 4, 6, 7, 8
#     * (2) TD tris : Exercice 5
#
# ## Pour la prochaine séance :
#
# * Terminer l'exercice_5 de `Revisions_premiere/tris/TD_tris`. Le code python doit être déposé dans votre github (Au bon endroit !!). Pour ceux qui ne peuvent pas utiliser Thonny, 2 solutions :
#     1. Aller sur https://repl.it/ pour écrire et tester du code python **sans rien installer sur la machine**.
#     2. si meme la solution précédente n'est pas possible : écrire le code python sur feuille
#
# # Séance  10 : 28 septembre 2020 de 10h à12h - M. Billouard
# ## Activité en classe :
#
#     * (1) Correction de l'évaluation
#     * (2) Cours comment exploiter une Bdd a partir de Python
#     * (3) Td Exploitation d'une Bdd sous Python
#
# ## Pour la prochaine séance :
#
#     * Regarder la correction du DM dans le dossier correction
#
# # Séance  9 : 25 septembre 2020 de 8h à10h - M. Billouard
# ## Activité en classe :
#
#     * (1) Point avec les élèves sur la base de données
#     * (2) Evaluation sur les compétences acquises en base de données
#     * (3) pour les plus rapides continuer le Td Bdd "immeuble"
#
# ## Pour la prochaine séance :
#
#     * Regarder la correction du DM dans le dossier correction
#
#
# # Séance  8 : 21 septembre 2020 de 10h à 12h - M. Billouard
# ## Activité en classe :
#
#     * (1) Cours comment exploiter une Bdd a partir de Python
#
# ## Pour la prochaine séance :
#     * Revoir l'ensemble du cours sur les bases de données
#     * Arriver à la requête 10 du Td Bdd "immeuble"
#     * Revoir l'ensemble du Bloc 2 sur les base de données (Evaluation)
#
# # Séance  7 : 18 septembre 2020 de 8h à 10h - M. Billouard
# ## Activité en classe :
#
#     * (1) Apport de précision concernant le DM
#     * (2) Poursuite du Td sur base de donnée Immeuble
#
# ## Pour la prochaine séance :
#     * DM a rendre obligatoirement (Version numérique ou papier)
#     * Revoir l'ensemble du cours sur les bases de données
#
# # Séance  6 : 17 septembre 2020 de 9h à 11h - M. Seynave
# ## Activité en classe :
#
# * **Revisions_premiere**
#     * (1) Correction TD tris exercices 3
#     * (2) cours tri par insertion
#     * (5) TD tris exercice 4
#
# ## Pour la prochaine séance :
#
# * **cours du jeudi 24 septembre annulé** (convocation au rectorat)
# * TD_tris : faire les exercices 6, 7 et 8. A faire sur feuille sauf la question 2 de l'exercice 6 qui doit être faite sur machine et déposée dans votre repository travail sur votre compte github (en cas de problème informatique, faire cette question 2 également sur feuille).
# * Vous avez 15 jours pour faire ces 3 exercices !!!
# * (Re)lire (Re)pratiquer les activités de la séance 6
#
#
# # Séance 5 : 11 septembre 2020 de  8h à 10h - M. Billouard
# ## Activité en classe :
# *
#     * Correction de l'exercice fait à la maison
#     * Td sur base de donnée Immeuble
#
#
# ## Pour la prochaine séance :
# *
#     * Revoir le cours sur la base de donnée
#     * Revoir les termes abordés ( relation, T-uplet, domaine etc ...)
#
# Pour le vendredi 18 septembre :
#    * Faire le DM N°1, lien du Git [DM1_ville](https://github.com/seynave/terminale/blob/master/Bloc2/DM1_Ville.ipynb)
#    * Le déposer sur votre Github
#     *(Pour ceux qui n'ont pas accès à un ordinateur, le DM sera fait sur feuille)*<br>
# ####  Vous avez tous eu la version papier -> AUCUNE EXCUSE
#
#
# # Séance 4 : 10 septembre 2020 de 9h à 11h - M. Seynave
# ## Activité en classe :
#
# * **Revisions_premiere**
#     * (1) fin du cours_introduction_aux_algorithmes_de_tris.ipyn
#     * (2) synthèse Activités manuelles : découverte des tris
#     * (3) TD tris exercices 1 et 2
#     * (4) cours tri par sélection
#     * (5) TD tris exercice 3
#
#
# ## Pour la prochaine séance :
#
# * terminer TD_tris exercice 3 (tri2)
# * TD_tris exercice 4
# * (Re)lire (Re)pratiquer les activités de la séance 4
#
# # Séance 3 : 7 septembre 2020 de  10h à 12h - M. Billouard
# ## Activité en classe :
# *
#     * Le langage Sql
#     * Td sur le langage Sql sous DB Browser (SQLite)
#
#
# ## Pour la prochaine séance :
# *
#     * Revoir le cours sur la base de donnée
#     * Revoir les termes abordés ( relation, T-uplet, domaine etc ...)
#
# **Exercice :** (Pour le 11 Septembre)
#
# On considère la base de donnée "Classe.db" ayant trois relations (tables) :
#
# Eleve(Id,Nom,Prenom,Adresse)<br>
# Note(Id,IdEleve,Idmatiere,note,date)<br>
# Matiere(Id,NomMatiere)
#
# vous indiquerez les différents domaines des attributs pour chaque relations.
#
# Réaliser le schéma relationnel de cette base de donnée
# (Cf : /Bloc2/2_La_BDD_relationnelle)
#
# On souhaite pouvoir obtenir :
#
#     1) La moyenne générale de la classe par matière.
#     2) La moyenne des notes par élève et par matière.
#     3) Le nom de la matière,la note plus faible, la plus élevé les dates correspondantes.
#
# Vous écrirez les trois requêtes.
#
# # Séance 2 : 4 septembre 2020 de 8h à 10h - M. Billouard
# ## Activité en classe :
# *
#     * (1) Présentation de la base de donnée.
#     * (2) Focus sur la base de donnée relationnelle.
#     * Exercices sur la structure de la base de donnée relationnelle.
#
#
# ## Pour la prochaine séance :
# *
#     * Réaliser le Schéma relationnel correnspondant à la base de données Bibliothèque suivante :
#
# Etudiant(**NumEtd**,NomEtd,PrenomEdt,AdresseEtd)<br>
# Livre(**NumLivre**,TitreLivre,*NumAuteur*,*NumEditeur*,*NumTheme*,AnneeEdition)<br>
# Auteur(**NumAuteur**,NomAuteur,AdresseAuteur)<br>
# Editeur(**NumEditeur*,NomEditeur,AdresseEditeur)<br>
# Theme(**NumTheme**,IntituléTheme)<br>
# Prêt(**NumEtd**,**NumLivre**,**DatePret**,DateRetour)<br>
#
# En **gras** les clés primaires et en *italique* les clés étrangères
#
# vous indiquerez les différents domaines des attributs pour chaque relations.
#
#
# # Séance 1 : 3 septembre 2020 de 9h à 11h - M. Seynave
# ## Activité en classe :
# * **Rentrée :**
#     * (1) Présentation de l'année de terminale et des épreuves de baccalauréat
#     * (2) Création d'un _repository_ privé sur **github**
#
#
# * **Revisions_premiere**
# 	* (2) Cours complexité d'un algorithme
#     * (3) Activités manuelles : découverte des tris
#     * (4) cours_introduction_aux_algorithmes_de_tris.ipynb
#
# ## Pour la prochaine séance :
#   * Ecrire en français l'algorithme de tri que vous avez trouvé.
#
#
# # Planning prévisionnel...
#
# # Séance  : 7 janvier 2021 de 9h à 11h - M. Seynave
# ## Activité en classe :
#
# * **bloc1/POO**
#     * TD_POO : correction de l'exercice 3
#     * Fin du Cours complément à la POO (partie sur méthodes spéciales)
#     * TD_POO : exercices 2.2, 5 et 5
#
# ## Pour la prochaine séance :
#
#
#
#
# ## M. Billouard (4h/semaine)
#
# * Base de données
# * Architecture, réseaux et système d'exploitation
# * graphes et arbres - (structure de données)
# * graphes et arbres - (algorithmes)
# * 2 algorithmes parmi méthode diviser pour régner, programmation dynamique et recherche textuelle
# * modularité, paradigme de programmation, mise au point et gestion des bugs - (Langage et programmation)
# * PROJETS
#
# ## M. Seynave (2h/semaine)
#
# * Révisions de première : tri par sélection / insertion. Rappel sur la complexité
# * récursivité - (Langage et programmation)
# * programmation orientée objet
# * liste chaînée - (structure de données)
# * piles et files - (structure de données)
# * Programme en tant que donnée : calculabilité et décidabilité - (Langage et programmation)
# * 1 algorithme parmi méthode diviser pour régner, programmation dynamique et recherche textuelle
# * modularité, paradigme de programmation, mise au point et gestion des bugs - (Langage et programmation)
# * PROJETS

# %% [markdown]
# ## M. Billouard (4h/semaine)
#
#  * Continuité pédagogique si les circonstances l'exigent.
#  * Lien Pour les Visio conférences :
#     * [Lien 1 (prioritaire)](https://web-visio.ac-lille.fr/TerminalNSIJR) pass :nsiJR
#     * [Lien 2 (secours)](https://teams.microsoft.com/l/meetup-join/19%3aab03e5afb372406d8c31f6a4d2fc5436%40thread.tacv2/1604589499262?context=%7b%22Tid%22%3a%2239e599f8-1278-41c8-9eca-888cdfced0ff%22%2c%22Oid%22%3a%22d51d1f2a-cbb9-4711-ab4d-8a8ac1bbe9c3%22%7d)
#  * Nom de connexion : Prenom N
