# %% [markdown]
# # Evaluation des acquis : Base de données relationnelle
#
# *Nom*...........................<br>
# *Prenom*........................<br>
# *Classe*........................<br>
#
# #### A) *Savoir distinguer la structure d’une base de données de son contenu.*
#
# * 1) Completer le schéma relationnel de la base données "Note_Eleve"
#
#    ![Eval1](img/Eval_1.PNG)
#
# * 2) Identifier les différents constituant de la table "Eleve".
#
#    ![Eval2](img/Eval_2.PNG)<br>
#
# Donner :<br>
#
# * 1) les domaines pour les différents attibuts de la table "Eleve"
# * 2) le nom de l'attribut utilisé en tant que clé primaire.
#
# #### B) *Repérer des anomalies dans le schéma d’une base de données.*
#
#       Je souhaite ajouter l'enregistrement suivant :
#
#        Id |  Nom  | Prenom |   Adresse
#         2 | "Bob" |"Hendri"| "Ap 360 Taciti Street"
#
# * 1) Que va t'il se passer ?
# * 2) Proposer une modification des données à insérer le cas échéant.
#
# #### C) *Construire des requêtes d’interrogation à l’aide des clauses du langage SQL.*
#
# * 1) Ecrire une requête Sql permettant de selectionner le prénom des élèves.
# * 2) Ecrire une requête permettant de supprimer "nathan bush" de la table "Eleve".
#
# #### D) *Identifier les services rendus par un système de gestion de bases de données relationnelles*
#
#    Au secours !!!
#
#    J'ai un petit carnet dans ma poche avec un répertoire téléphonique d'environ 500 personnes, la recherche dans le carnet commence à être fastidieuse.
#    Quand je prends mon carnet à l'envers, j'ai des contacts de réseaux sociaux TeteBook,Radiogam, Gazouilleteur etc...
#    Tout est mélangé et parfois en plus du pseudo, j'ai aussi le nom et le prénom.
#
#    Pour résumer trouver toutes les informations d'une personne relève de l'exploit.
#
#    J'aimerais pouvoir rapidement accéder aux données que je recherche rapidement, et pouvoir retrouver, par exemple les numéros de téléphone de mes contacts TeteBook que je possède.
#
#    J'hésite entre créer un gros fichier ou utiliser une base de données.
#
#    j'aurais besoin que la recherche soit rapide et que ce que je récupère soit les bonnes.
#    j'ai aussi besoin que les données soient toujours accessibles et qu'elles ne se perdent pas.
#
#    Aidez moi a choisir en justifiant vos réponses.(il n'y a pas de requête a donner ici)
#
# #### E) *Festival de musique*
#
#    On dispose d'une base données d'un festval de musique, où il y a plusieurs représentations.
#    Le schéma relationnel de la base de donnée est donnée ci-dessous.
#
#    ![Musi](img/festival_musique.PNG)
#
#    Ecrire les requêtes Sql permettant d'afficher :<br>
#
#     * La liste des titres des représentations.
#
#     * La liste des titres des représentations ayant lieu a "Dionysos"
#
#     * La liste des noms des musiciens et les titres des représentations auxquelles ils participent.
#
#     * La liste des titres de représentations, les lieux et les tarifs pour la date du 30 novembre.(30/11/2020)
#
#     * Le nombre de musiciens qui participent à la représentation numéro 7.
#
#     * Les représéntations et leurs dates dont le tarif ne dépasse pas 30€
#
#     * Supprimer les programmations qui devaient avoir lieu le 26 janvier 2021 (26/01/2021)
